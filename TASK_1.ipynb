# %% [markdown]
# <a href="https://colab.research.google.com/github/aksaini175/Cognifyz-Internship-Level-1/blob/main/TASK_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('/Dataset .csv')

# %%
df_cuisines = df["Cuisines"].dropna()

# %% [markdown]
# Determine The Top Three Most Common **Cuisines**

# %%
df.columns = df.columns.str.strip()


cuisine_count = (
    df['Cuisines']
    .dropna()
    .str.split(',')
    .explode()
    .str.strip()
    .value_counts()
)


top_three_cuisine = cuisine_count.head(3)

print(top_three_cuisine)
# Out:
# Cuisines
# North Indian    3960
# Chinese         2735
# Fast Food       1986
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

colors = ['green', 'yellow', 'red']

plt.bar(top_three_cuisine.index, top_three_cuisine.values, color=colors)
plt.title("The Top Three Most Common Cuisines")
plt.xlabel("Cuisines")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Calculate The Percentage of Restaurants That Serve Each of The Top **Cuisines**

# %%
# Make sure the Cuisines column is clean
df.columns = df.columns.str.strip()

# Remove missing cuisine values
df_cuisines = df['Cuisines'].dropna()

# Total number of restaurants
total_restaurants = len(df_cuisines)

# Percentage of restaurants serving each top cuisine
top_cuisines_percentage = (top_three_cuisine / total_restaurants) * 100

print(top_cuisines_percentage)
# Out:
# Cuisines
# North Indian    41.500734
# Chinese         28.662754
# Fast Food       20.813247
# Name: count, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 6))
plt.pie(
    top_three_cuisine.values,
    labels=top_three_cuisine.index,
    autopct='%1.1f%%',
    startangle=90
)
plt.title("The Percentage of Restaurants That Serve Each of The Top Cuisines")
plt.axis('equal')  # Makes the pie a perfect circle
plt.show()
